# %% [markdown]
# ## Unstructured Document Rertriveal Pipeline

# %%
# 1. SETUP - Install once
# pip install langchain langchain-community langchain-unstructured chromadb langchain-openai unstructured[local-inference]

from langchain_community.document_loaders import DirectoryLoader
from langchain_unstructured import UnstructuredLoader
from unstructured.cleaners.core import clean_extra_whitespace
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma

# 2. LOAD PDFs → Elements (30-60 mins)
loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=UnstructuredLoader,
    loader_kwargs={
        "mode": "elements",
        "strategy": "fast",           # Quick text extraction
        "post_processors": [clean_extra_whitespace],
        "languages": ["eng"],
    },
    use_multithreading=True,
    show_progress=True
)

print("Loading 1074 PDFs...")
docs = loader.load()  # ~40k elements
print(f"Loaded: {len(docs)} elements")
# Out:
# Loading 1074 PDFs...
#   0%|          | 0/1076 [00:00<?, ?it/s]INFO: pikepdf C++ to Python logger bridge initialized
#   2%|▏         | 20/1076 [00:20<17:27,  1.01it/s] WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\2GFKZ3FSJWFKVKALUPEYHSLSHEJ3OGA6.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#   6%|▌         | 60/1076 [01:53<09:21,  1.81it/s]  WARNING: Pattern color space requires name object (PSLiteral), got int: 0. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got int: 1. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got int: 0. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got int: 1. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got int: 0. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
#   6%|▌         | 65/1076 [02:04<29:55,  1.78s/it]WARNING: Execute called on non-indirect object (inline image?) <PDFStream(None): raw=0, {}>
#   8%|▊         | 88/1076 [02:33<22:22,  1.36s/it]INFO: PDF text extraction failed, skip text extraction...
#  12%|█▏        | 134/1076 [03:24<11:04,  1.42it/s]WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\6C4F5OS4HOEBDQEKSVUX42XOMOJG3BNW.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#  13%|█▎        | 144/1076 [03:28<04:27,  3.48it/s]WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# INFO: PDF text extraction failed, skip text extraction...
#  19%|█▉        | 206/1076 [04:38<17:18,  1.19s/it]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  21%|██        | 227/1076 [05:14<24:26,  1.73s/it]WARNING: Pattern color space requires name object (PSLiteral), got int: 0. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got float: 0.502. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
# WARNING: Pattern color space requires name object (PSLiteral), got float: 0.502. Per ISO 32000 8.7.3.2, colored patterns use syntax '/name scn'. Per ISO 32000 8.7.3.3, uncolored patterns use syntax 'c1...cn /name scn'.
#  23%|██▎       | 246/1076 [05:34<22:49,  1.65s/it]WARNING: Cannot set non-stroke color because expected 3 components but got [0.9]
# WARNING: Cannot set non-stroke color because expected 3 components but got [0.9]
# WARNING: Cannot set non-stroke color because expected 3 components but got [0.9]
# WARNING: Cannot set non-stroke color because expected 3 components but got [0.9]
# WARNING: Cannot set non-stroke color because expected 3 components but got [0.9]
#  26%|██▌       | 276/1076 [06:08<03:40,  3.63it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  26%|██▌       | 278/1076 [06:09<04:37,  2.88it/s]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  26%|██▌       | 279/1076 [06:10<06:41,  1.99it/s]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  27%|██▋       | 291/1076 [06:14<06:12,  2.11it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.3]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.15]
#  27%|██▋       | 294/1076 [06:16<07:59,  1.63it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  27%|██▋       | 295/1076 [06:18<10:15,  1.27it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  28%|██▊       | 297/1076 [06:18<07:07,  1.82it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.7]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.7]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  30%|███       | 324/1076 [06:30<04:44,  2.64it/s]WARNING: Cannot set stroke color: /'P0' is an invalid float value
# WARNING: Cannot set stroke color: /'P1' is an invalid float value
# WARNING: Cannot set stroke color: /'P2' is an invalid float value
# WARNING: Cannot set stroke color: /'P3' is an invalid float value
# WARNING: Cannot set stroke color: /'P4' is an invalid float value
# WARNING: Cannot set stroke color: /'P5' is an invalid float value
#  31%|███       | 333/1076 [06:34<03:43,  3.32it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  32%|███▏      | 343/1076 [06:44<15:36,  1.28s/it]WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\DROYHKJATHTGQRNXG6PEDVKVXILMNNET.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#  32%|███▏      | 344/1076 [06:45<16:02,  1.31s/it]INFO: PDF text extraction failed, skip text extraction...
#  34%|███▍      | 368/1076 [06:53<03:38,  3.23it/s]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  35%|███▌      | 378/1076 [06:57<04:27,  2.61it/s]WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\EKYCT6JDYSVHCFQPJSCTM7VEB5GEUPWR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#  36%|███▌      | 382/1076 [06:59<04:03,  2.85it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  36%|███▌      | 383/1076 [06:59<04:50,  2.39it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  36%|███▌      | 390/1076 [07:02<05:00,  2.28it/s]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  36%|███▋      | 391/1076 [07:03<05:25,  2.10it/s]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  39%|███▉      | 424/1076 [07:16<03:14,  3.35it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.2]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  39%|███▉      | 425/1076 [07:17<04:13,  2.56it/s]WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\FVIKHA7GEB6QLKRNAPQD63GXPARVH3KX.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#  42%|████▏     | 450/1076 [07:41<07:27,  1.40it/s]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.769531]
# WARNING: Cannot set stroke color because expected 4 components but got [0.769531]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.149902]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.149902]
#  42%|████▏     | 451/1076 [07:44<14:58,  1.44s/it]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
#  42%|████▏     | 452/1076 [07:45<12:41,  1.22s/it]WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
#  42%|████▏     | 453/1076 [07:47<14:28,  1.39s/it]WARNING: Cannot set stroke color because expected 4 components but got [0.100098]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [0.409912]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [0.599609]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  42%|████▏     | 454/1076 [07:48<14:11,  1.37s/it]WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
#  42%|████▏     | 455/1076 [07:50<16:34,  1.60s/it]WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
#  42%|████▏     | 456/1076 [07:50<12:02,  1.17s/it]WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set non-stroke color because expected 4 components but got [0.00101089]
# WARNING: Cannot set stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
# WARNING: Cannot set non-stroke color because expected 4 components but got [1]
#  43%|████▎     | 467/1076 [08:03<07:19,  1.39it/s]WARNING: The PDF <_io.BufferedReader name='..\\data\\pdf\\HDUWFMUR5BA3PDSRTCJMNFUNYZ7OWHQ2.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
#  49%|████▉     | 530/1076 [09:24<14:47,  1.63s/it]WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P1' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P2' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P3' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P1' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
# WARNING: Cannot set non-stroke color: /'P0' is an invalid float value
#  50%|█████     | 538/1076 [10:44<1:54:05, 12.72s/it]

# %%
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
import glob

# 1. Ollama embeddings
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# 2. Load and CLEAN metadata during loading (your 504K elements already loaded)
def clean_metadata_for_chroma(metadata):
    """Convert all lists/objects to strings for Chroma compatibility"""
    cleaned = {}
    for key, value in metadata.items():
        if key in ["coordinates", "element_id", "parent_id"]:
            continue  # Skip complex fields entirely
        elif isinstance(value, list):
            cleaned[key] = ",".join(str(v) for v in value)  # ["eng"] → "eng"
        elif isinstance(value, dict):
            continue  # Skip dicts entirely
        else:
            cleaned[key] = value
    return cleaned

# Re-process your loaded elements with clean metadata
print("Cleaning metadata for Chroma...")
cleaned_elements = []
for doc in all_elements:
    cleaned_metadata = clean_metadata_for_chroma(doc.metadata)
    cleaned_doc = Document(
        page_content=doc.page_content,
        metadata=cleaned_metadata
    )
    cleaned_elements.append(cleaned_doc)

print(f"Cleaned metadata complete: {len(cleaned_elements)} documents")

# 3. Split large elements
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.split_documents(cleaned_elements)
print(f"Final chunks ready: {len(chunks)}")

# 4. BATCHED embedding (500K chunks needs batches)
print("Starting batched embedding...")
vectorstore = None
batch_size = 3000  # Conservative batch size

for i in range(0, len(chunks), batch_size):
    batch = chunks[i:i+batch_size]
    print(f"Batch {i//batch_size + 1}: {len(batch)} chunks ({i+len(batch)}/{len(chunks)})")
    
    if vectorstore is None:
        vectorstore = Chroma.from_documents(
            documents=batch,
            embedding=embeddings,
            persist_directory="./chroma_smart_elements",
            collection_name="humanitarian_data"
        )
    else:
        vectorstore.add_documents(batch)

print(f"Success! {vectorstore._collection.count()} chunks indexed in ./chroma_smart_elements")
# Out:
# Cleaning metadata for Chroma...
# Cleaned metadata complete: 504065 documents
# Final chunks ready: 502106
# Starting batched embedding...
# Batch 1: 3000 chunks (3000/502106)
# Batch 2: 3000 chunks (6000/502106)
# Batch 3: 3000 chunks (9000/502106)
# Batch 4: 3000 chunks (12000/502106)
# Batch 5: 3000 chunks (15000/502106)
# Batch 6: 3000 chunks (18000/502106)
# Batch 7: 3000 chunks (21000/502106)
# Batch 8: 3000 chunks (24000/502106)
# Batch 9: 3000 chunks (27000/502106)
# Batch 10: 3000 chunks (30000/502106)
# Batch 11: 3000 chunks (33000/502106)
# Batch 12: 3000 chunks (36000/502106)
# Batch 13: 3000 chunks (39000/502106)
# Batch 14: 3000 chunks (42000/502106)
# Batch 15: 3000 chunks (45000/502106)
# Batch 16: 3000 chunks (48000/502106)
# Batch 17: 3000 chunks (51000/502106)
# Batch 18: 3000 chunks (54000/502106)
# Batch 19: 3000 chunks (57000/502106)
# Batch 20: 3000 chunks (60000/502106)
# Batch 21: 3000 chunks (63000/502106)
# Batch 22: 3000 chunks (66000/502106)
# Batch 23: 3000 chunks (69000/502106)
# Batch 24: 3000 chunks (72000/502106)
# Batch 25: 3000 chunks (75000/502106)
# Batch 26: 3000 chunks (78000/502106)
# Batch 27: 3000 chunks (81000/502106)
# Batch 28: 3000 chunks (84000/502106)
# Batch 29: 3000 chunks (87000/502106)
# Batch 30: 3000 chunks (90000/502106)
# Batch 31: 3000 chunks (93000/502106)
# Batch 32: 3000 chunks (96000/502106)
# Batch 33: 3000 chunks (99000/502106)
# Batch 34: 3000 chunks (102000/502106)
# Batch 35: 3000 chunks (105000/502106)
# Batch 36: 3000 chunks (108000/502106)
# Batch 37: 3000 chunks (111000/502106)
# Batch 38: 3000 chunks (114000/502106)
# Batch 39: 3000 chunks (117000/502106)
# Batch 40: 3000 chunks (120000/502106)
# Batch 41: 3000 chunks (123000/502106)
# Batch 42: 3000 chunks (126000/502106)
# Batch 43: 3000 chunks (129000/502106)
# Batch 44: 3000 chunks (132000/502106)
# Batch 45: 3000 chunks (135000/502106)
# Batch 46: 3000 chunks (138000/502106)
# Batch 47: 3000 chunks (141000/502106)
# Batch 48: 3000 chunks (144000/502106)
# Batch 49: 3000 chunks (147000/502106)
# Batch 50: 3000 chunks (150000/502106)
# Batch 51: 3000 chunks (153000/502106)
# Batch 52: 3000 chunks (156000/502106)
# Batch 53: 3000 chunks (159000/502106)
# Batch 54: 3000 chunks (162000/502106)
# Batch 55: 3000 chunks (165000/502106)
# Batch 56: 3000 chunks (168000/502106)
# Batch 57: 3000 chunks (171000/502106)
# Batch 58: 3000 chunks (174000/502106)
# Batch 59: 3000 chunks (177000/502106)
# Batch 60: 3000 chunks (180000/502106)
# Batch 61: 3000 chunks (183000/502106)
# Batch 62: 3000 chunks (186000/502106)
# Batch 63: 3000 chunks (189000/502106)
# Batch 64: 3000 chunks (192000/502106)
# Batch 65: 3000 chunks (195000/502106)
# Batch 66: 3000 chunks (198000/502106)
# Batch 67: 3000 chunks (201000/502106)
# Batch 68: 3000 chunks (204000/502106)
# Batch 69: 3000 chunks (207000/502106)
# Batch 70: 3000 chunks (210000/502106)
# Batch 71: 3000 chunks (213000/502106)
# Batch 72: 3000 chunks (216000/502106)
# Batch 73: 3000 chunks (219000/502106)
# Batch 74: 3000 chunks (222000/502106)
# Batch 75: 3000 chunks (225000/502106)
# Batch 76: 3000 chunks (228000/502106)
# Batch 77: 3000 chunks (231000/502106)
# Batch 78: 3000 chunks (234000/502106)
# Batch 79: 3000 chunks (237000/502106)
# Batch 80: 3000 chunks (240000/502106)
# Batch 81: 3000 chunks (243000/502106)
# Batch 82: 3000 chunks (246000/502106)
# Batch 83: 3000 chunks (249000/502106)
# Batch 84: 3000 chunks (252000/502106)
# Batch 85: 3000 chunks (255000/502106)
# Batch 86: 3000 chunks (258000/502106)
# Batch 87: 3000 chunks (261000/502106)
# Batch 88: 3000 chunks (264000/502106)
# Batch 89: 3000 chunks (267000/502106)
# Batch 90: 3000 chunks (270000/502106)
# Batch 91: 3000 chunks (273000/502106)
# Batch 92: 3000 chunks (276000/502106)
# Batch 93: 3000 chunks (279000/502106)
# Batch 94: 3000 chunks (282000/502106)
# Batch 95: 3000 chunks (285000/502106)
# Batch 96: 3000 chunks (288000/502106)
# Batch 97: 3000 chunks (291000/502106)
# Batch 98: 3000 chunks (294000/502106)
# Batch 99: 3000 chunks (297000/502106)
# Batch 100: 3000 chunks (300000/502106)
# Batch 101: 3000 chunks (303000/502106)
# Batch 102: 3000 chunks (306000/502106)
# Batch 103: 3000 chunks (309000/502106)
# Batch 104: 3000 chunks (312000/502106)
# Batch 105: 3000 chunks (315000/502106)
# Batch 106: 3000 chunks (318000/502106)
# Batch 107: 3000 chunks (321000/502106)
# Batch 108: 3000 chunks (324000/502106)
# Batch 109: 3000 chunks (327000/502106)
# Batch 110: 3000 chunks (330000/502106)
# Batch 111: 3000 chunks (333000/502106)
# Batch 112: 3000 chunks (336000/502106)
# Batch 113: 3000 chunks (339000/502106)
# Batch 114: 3000 chunks (342000/502106)
# Batch 115: 3000 chunks (345000/502106)
# Batch 116: 3000 chunks (348000/502106)
# Batch 117: 3000 chunks (351000/502106)
# Batch 118: 3000 chunks (354000/502106)
# Batch 119: 3000 chunks (357000/502106)
# Batch 120: 3000 chunks (360000/502106)
# Batch 121: 3000 chunks (363000/502106)
# Batch 122: 3000 chunks (366000/502106)
# Batch 123: 3000 chunks (369000/502106)
# Batch 124: 3000 chunks (372000/502106)
# Batch 125: 3000 chunks (375000/502106)
# Batch 126: 3000 chunks (378000/502106)
# Batch 127: 3000 chunks (381000/502106)
# Batch 128: 3000 chunks (384000/502106)
# Batch 129: 3000 chunks (387000/502106)
# Batch 130: 3000 chunks (390000/502106)
# Batch 131: 3000 chunks (393000/502106)
# Batch 132: 3000 chunks (396000/502106)
# Batch 133: 3000 chunks (399000/502106)
# Batch 134: 3000 chunks (402000/502106)
# Batch 135: 3000 chunks (405000/502106)
# Batch 136: 3000 chunks (408000/502106)
# Batch 137: 3000 chunks (411000/502106)
# Batch 138: 3000 chunks (414000/502106)
# Batch 139: 3000 chunks (417000/502106)
# Batch 140: 3000 chunks (420000/502106)
# Batch 141: 3000 chunks (423000/502106)
# Batch 142: 3000 chunks (426000/502106)
# Batch 143: 3000 chunks (429000/502106)
# Batch 144: 3000 chunks (432000/502106)
# Batch 145: 3000 chunks (435000/502106)
# Batch 146: 3000 chunks (438000/502106)
# Batch 147: 3000 chunks (441000/502106)
# Batch 148: 3000 chunks (444000/502106)
# Batch 149: 3000 chunks (447000/502106)
# Batch 150: 3000 chunks (450000/502106)
# Batch 151: 3000 chunks (453000/502106)
# Batch 152: 3000 chunks (456000/502106)
# Batch 153: 3000 chunks (459000/502106)
# Batch 154: 3000 chunks (462000/502106)
# Batch 155: 3000 chunks (465000/502106)
# Batch 156: 3000 chunks (468000/502106)
# Batch 157: 3000 chunks (471000/502106)
# Batch 158: 3000 chunks (474000/502106)
# Batch 159: 3000 chunks (477000/502106)
# Batch 160: 3000 chunks (480000/502106)
# Batch 161: 3000 chunks (483000/502106)
# Batch 162: 3000 chunks (486000/502106)
# Batch 163: 3000 chunks (489000/502106)
# Batch 164: 3000 chunks (492000/502106)
# Batch 165: 3000 chunks (495000/502106)
# Batch 166: 3000 chunks (498000/502106)
# Batch 167: 3000 chunks (501000/502106)
# Batch 168: 1106 chunks (502106/502106)
# Success! 502106 chunks indexed in ./chroma_smart_elements

# %%
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings

# Load your completed index
embeddings = OllamaEmbeddings(model="nomic-embed-text")
vectorstore = Chroma(
    persist_directory="./chroma_smart_elements",
    collection_name="humanitarian_data",
    embedding_function=embeddings
)

print(f"Loaded: {vectorstore._collection.count()} vectors")

# Test queries
test_queries = [
    "donor data sharing risks",
    "humanitarian data responsibility", 
    "key takeaways data sharing",
    "ACRONYMS",
    "What is Congressional Record?"
]

for query in test_queries:
    results = vectorstore.similarity_search(query, k=7)
    print(f"\nQuery: '{query}'")
    for i, doc in enumerate(results, 1):
        print(f"  {i}. [{doc.metadata['category']}] {doc.metadata['filename'][:25]} (pg {doc.metadata['page_number']})")
        print(f"     {doc.page_content[:150]}...")
# Out:
# Loaded: 502106 vectors
#
# Query: 'donor data sharing risks'
#   1. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 154)
#      ....
#   2. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 170)
#      ....
#   3. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 179)
#      ....
#   4. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 180)
#      ....
#   5. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 189)
#      ....
#   6. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 217)
#      ....
#   7. [UncategorizedText] 2544CYX3TC3T5QB2NTVXD3IUF (pg 237)
#      ....
#
# Query: 'humanitarian data responsibility'
#   1. [Header] e86f389121e94e5a65f89285a (pg 5)
#      Scenarios in humanitarian data management...
#   2. [Header] e86f389121e94e5a65f89285a (pg 5)
#      Scenarios in humanitarian data management...
#   3. [NarrativeText] 642c5aed3f342a15e2ae287d5 (pg 4)
#      Section 1: Introduction offers an overview of key concepts related to data responsibility in humanitarian action, explains the role of OCHA in humanit...
#   4. [NarrativeText] e86f389121e94e5a65f89285a (pg 1)
#      Data responsibility is the safe, ethical and effective management of data.1 This note focuses on the ethical aspects of humanitarian data management, ...
#   5. [NarrativeText] e86f389121e94e5a65f89285a (pg 1)
#      Data responsibility is the safe, ethical and effective management of data.1 This note focuses on the ethical aspects of humanitarian data management, ...
#   6. [NarrativeText] 3fd6a0981cec7cf21e133249f (pg 1)
#      This Guidance Note explores data responsibility and AAP in humanitarian action. It identifies common data-related benefits and risks related to AAP, e...
#   7. [NarrativeText] 6fb1b50dc88bf6c0bb775bf32 (pg 2)
#      Public and private sector actors have held a number of convenings and events on this topic, but there is still no common understanding around the requ...
#
# Query: 'key takeaways data sharing'
#   1. [Footer] f997183fa6bf1ef75e31406d9 (pg 22)
#      log. Information on data sharing should include, at a minimum, the recipient, sharing...
#   2. [ListItem] fb8c6201bfd519374fe7aba96 (pg 4)
#      Establish data sharing agreements for the exchange of personal data...
#   3. [ListItem] d5b25fe1a9b3ab5d54dfc8855 (pg 19)
#      Continuous development of products and services that demonstrate the value of shared data....
#   4. [ListItem] cdc0d42854a09a33d44b0c72d (pg 1)
#      Data sharing, including the websites, reports and information products the data management activity will contribute to....
#   5. [ListItem] cdc0d42854a09a33d44b0c72d (pg 2)
#      3. The AWG shares disaggregated data with the clusters for analysis, which the clusters share back with the AWG once complete. The AWG also shares agg...
#   6. [ListItem] d5b25fe1a9b3ab5d54dfc8855 (pg 10)
#      Demonstrate the value of making data accessible: Information is predominately shared in the form of documents. Disaggregated data is needed for analys...
#   7. [NarrativeText] 380cadf4f7caa0146071865cc (pg 5)
#      Assessment results should be shared to the extent possible and as long as it does not expose confidential or otherwise sensitive information....
#
# Query: 'ACRONYMS'
#   1. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 486)
#      References...
#   2. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 527)
#      I...
#   3. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 531)
#      CLOSE...
#   4. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 538)
#      Supplements...
#   5. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 539)
#      CP...
#   6. [UncategorizedText] SECTG7BZB6D4FVDAZNN2DTF2G (pg 539)
#      Y50...
#   7. [Title] SECTG7BZB6D4FVDAZNN2DTF2G (pg 543)
#      Pump...
#
# Query: 'What is Congressional Record?'
#   1. [Title] INE663VOPVFVXLNIIAX5ZESMK (pg 12)
#      P (Pass)...
#   2. [Title] INE663VOPVFVXLNIIAX5ZESMK (pg 12)
#      I (Inconclusive)...
#   3. [Title] NLALJLUHGUMMXT4J7U6N334L5 (pg 1)
#      Fatalities (FARS)...
#   4. [Title] NLALJLUHGUMMXT4J7U6N334L5 (pg 1)
#      Injuries (MCMIS)...
#   5. [Title] NLALJLUHGUMMXT4J7U6N334L5 (pg 1)
#      Fatalities (FARS)...
#   6. [Title] NLALJLUHGUMMXT4J7U6N334L5 (pg 1)
#      Injuries (MCMIS)...
#   7. [Title] 5LJK3WBGEWURVXHBKF7FQP32F (pg 1)
#      Name of PAC Primary Officer ? ?...
